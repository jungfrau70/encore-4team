# %% [markdown]
# <a href="https://colab.research.google.com/github/jungfrau70/encore-4team/blob/main/4_TF2_iris_(%EB%AC%B8%EC%A0%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# data = tfds.load("iris", split=tfds.Split.TRAIN.subsplit(tfds.percent[:80]))
train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, depth=3)
    return x, y


def solution_model():
    train_ds = train_dataset.map(preprocess).batch(10)
    valid_ds = valid_dataset.map(preprocess).batch(10)

    model = Sequential([
        Dense(64, activation='tanh', input_shape=[4]),
        # Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(3, activation='softmax'),
    ])

    model.summary()

    adam = tf.keras.optimizers.Adam(
        learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False
    )
    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['acc'])

    checkpoint_path = "my_checkpoing.ckpt"
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                                monitor='val_loss', 
                                verbose=1, 
                                save_best_only=True, 
                                save_weights_only=True,)

    model.fit(
            train_ds,
            epochs=30, 
            verbose=1, 
            callbacks=[checkpoint], 
            validation_data=(valid_ds)
            )

    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF2-iris.h5")
# Out:
# Downloading and preparing dataset iris/2.0.0 (download: 4.44 KiB, generated: Unknown size, total: 4.44 KiB) to /root/tensorflow_datasets/iris/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/iris/2.0.0.incomplete4AG9DO/iris-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# Dataset iris downloaded and prepared to /root/tensorflow_datasets/iris/2.0.0. Subsequent calls will reuse this data.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                320
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 2,499
# Trainable params: 2,499
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 12/12 [==============================] - 3s 54ms/step - loss: 0.9154 - acc: 0.6020 - val_loss: 0.5894 - val_acc: 0.6333
#
# Epoch 00001: val_loss improved from inf to 0.58942, saving model to my_checkpoing.ckpt
# Epoch 2/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.4563 - acc: 0.7204 - val_loss: 0.4432 - val_acc: 0.7000
#
# Epoch 00002: val_loss improved from 0.58942 to 0.44316, saving model to my_checkpoing.ckpt
# Epoch 3/30
# 12/12 [==============================] - 0s 14ms/step - loss: 0.3223 - acc: 0.7991 - val_loss: 0.3623 - val_acc: 0.8000
#
# Epoch 00003: val_loss improved from 0.44316 to 0.36230, saving model to my_checkpoing.ckpt
# Epoch 4/30
# 12/12 [==============================] - 0s 11ms/step - loss: 0.2123 - acc: 0.8974 - val_loss: 0.2956 - val_acc: 0.8667
#
# Epoch 00004: val_loss improved from 0.36230 to 0.29558, saving model to my_checkpoing.ckpt
# Epoch 5/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1283 - acc: 0.9384 - val_loss: 0.1637 - val_acc: 0.9333
#
# Epoch 00005: val_loss improved from 0.29558 to 0.16366, saving model to my_checkpoing.ckpt
# Epoch 6/30
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0980 - acc: 0.9773 - val_loss: 0.1407 - val_acc: 0.9333
#
# Epoch 00006: val_loss improved from 0.16366 to 0.14067, saving model to my_checkpoing.ckpt
# Epoch 7/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0518 - acc: 0.9987 - val_loss: 0.1587 - val_acc: 0.9333
#
# Epoch 00007: val_loss did not improve from 0.14067
# Epoch 8/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0374 - acc: 0.9987 - val_loss: 0.2200 - val_acc: 0.9000
#
# Epoch 00008: val_loss did not improve from 0.14067
# Epoch 9/30
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0596 - acc: 0.9746 - val_loss: 0.3095 - val_acc: 0.9000
#
# Epoch 00009: val_loss did not improve from 0.14067
# Epoch 10/30
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0401 - acc: 0.9846 - val_loss: 0.1240 - val_acc: 0.9667
#
# Epoch 00010: val_loss improved from 0.14067 to 0.12405, saving model to my_checkpoing.ckpt
# Epoch 11/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.1012 - acc: 0.9600 - val_loss: 0.1025 - val_acc: 0.9667
#
# Epoch 00011: val_loss improved from 0.12405 to 0.10249, saving model to my_checkpoing.ckpt
# Epoch 12/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0288 - acc: 0.9987 - val_loss: 0.1254 - val_acc: 0.9333
#
# Epoch 00012: val_loss did not improve from 0.10249
# Epoch 13/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0356 - acc: 0.9857 - val_loss: 0.1205 - val_acc: 0.9667
#
# Epoch 00013: val_loss did not improve from 0.10249
# Epoch 14/30
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0450 - acc: 0.9801 - val_loss: 0.1068 - val_acc: 0.9667
#
# Epoch 00014: val_loss did not improve from 0.10249
# Epoch 15/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0516 - acc: 0.9801 - val_loss: 0.1002 - val_acc: 0.9667
#
# Epoch 00015: val_loss improved from 0.10249 to 0.10020, saving model to my_checkpoing.ckpt
# Epoch 16/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0511 - acc: 0.9801 - val_loss: 0.1004 - val_acc: 0.9667
#
# Epoch 00016: val_loss did not improve from 0.10020
# Epoch 17/30
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0509 - acc: 0.9697 - val_loss: 0.1043 - val_acc: 0.9667
#
# Epoch 00017: val_loss did not improve from 0.10020
# Epoch 18/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0497 - acc: 0.9726 - val_loss: 0.1071 - val_acc: 0.9667
#
# Epoch 00018: val_loss did not improve from 0.10020
# Epoch 19/30
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0535 - acc: 0.9726 - val_loss: 0.1069 - val_acc: 0.9667
#
# Epoch 00019: val_loss did not improve from 0.10020
# Epoch 20/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0562 - acc: 0.9726 - val_loss: 0.1105 - val_acc: 0.9667
#
# Epoch 00020: val_loss did not improve from 0.10020
# Epoch 21/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0562 - acc: 0.9726 - val_loss: 0.1270 - val_acc: 0.9333
#
# Epoch 00021: val_loss did not improve from 0.10020
# Epoch 22/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0510 - acc: 0.9726 - val_loss: 0.1864 - val_acc: 0.9333
#
# Epoch 00022: val_loss did not improve from 0.10020
# Epoch 23/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0362 - acc: 0.9856 - val_loss: 0.1332 - val_acc: 0.9333
#
# Epoch 00023: val_loss did not improve from 0.10020
# Epoch 24/30
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0571 - acc: 0.9726 - val_loss: 0.1306 - val_acc: 0.9333
#
# Epoch 00024: val_loss did not improve from 0.10020
# Epoch 25/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0540 - acc: 0.9726 - val_loss: 0.1963 - val_acc: 0.9333
#
# Epoch 00025: val_loss did not improve from 0.10020
# Epoch 26/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0448 - acc: 0.9856 - val_loss: 0.3375 - val_acc: 0.9000
#
# Epoch 00026: val_loss did not improve from 0.10020
# Epoch 27/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0397 - acc: 0.9874 - val_loss: 0.5995 - val_acc: 0.8667
#
# Epoch 00027: val_loss did not improve from 0.10020
# Epoch 28/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0573 - acc: 0.9742 - val_loss: 0.4843 - val_acc: 0.9000
#
# Epoch 00028: val_loss did not improve from 0.10020
# Epoch 29/30
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0599 - acc: 0.9828 - val_loss: 0.2573 - val_acc: 0.9333
#
# Epoch 00029: val_loss did not improve from 0.10020
# Epoch 30/30
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0308 - acc: 0.9856 - val_loss: 0.2164 - val_acc: 0.9333
#
# Epoch 00030: val_loss did not improve from 0.10020

# %% [markdown]
# # 새 섹션

# %%
valid_ds = valid_dataset.map(preprocess).batch(10)
model = tf.keras.models.load_model("TF2-iris.h5")
model.evaluate(valid_ds)
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1002 - acc: 0.9667
# [0.10020295530557632, 0.9666666388511658]
